# %%
import pandas as pd

# %%
rute = pd.read_csv('rute.csv')

# %%
rute
# Out:
#       Airline Airline ID Source Source ID Destination Destination ID  \
# 0          2B        410    AER      2965         KZN           2990
# 1          2B        410    ASF      2966         KZN           2990
# 2          2B        410    ASF      2966         MRV           2962
# 3          2B        410    CEK      2968         KZN           2990
# 4          2B        410    CEK      2968         OVB           4078
# 5          2B        410    DME      4029         KZN           2990
# 6          2B        410    DME      4029         NBC           6969
# 7          2B        410    DME      4029         TGK             \N
# 8          2B        410    DME      4029         UUA           6160
# 9          2B        410    EGO      6156         KGD           2952
# 10         2B        410    EGO      6156         KZN           2990
# 11         2B        410    GYD      2922         NBC           6969
# 12         2B        410    KGD      2952         EGO           6156
# ...

# %%
aerodromi = pd.read_excel('aerodromi.xlsx')

# %%
aerodromi
# Out:
#        Airport ID                                         Name  \
# 0               1                               Goroka Airport
# 1               2                               Madang Airport
# 2               3                 Mount Hagen Kagamuga Airport
# 3               4                               Nadzab Airport
# 4               5  Port Moresby Jacksons International Airport
# 5               6                  Wewak International Airport
# 6               7                           Narsarsuaq Airport
# 7               8                      Godthaab / Nuuk Airport
# 8               9                        Kangerlussuaq Airport
# 9              10                               Thule Air Base
# 10             11                             Akureyri Airport
# 11             12                          Egilsstaðir Airport
# 12             13                         Hornafjörður Airport
# 13             14                              Húsavík Airport
# ...

# %%
airlines = pd.read_excel('airlines.xlsx')
airlines
# Out:
#          ID                                          Name  \
# 0        -1                                       Unknown
# 1         1                                Private flight
# 2         2                                   135 Airways
# 3         3                                 1Time Airline
# 4         4  2 Sqn No 1 Elementary Flying Training School
# 5         5                               213 Flight Unit
# 6         6                 223 Flight Unit State Airline
# 7         7                             224th Flight Unit
# 8         8                                   247 Jet Ltd
# 9         9                                   3D Aviation
# 10       10                                   40-Mile Air
# 11       11                                        4D Air
# 12       12                        611897 Alberta Limited
# 13       13                              Ansett Australia
# 14       14                          Abacus International
# ...

# %%
from IPython.display import Image

# %%
Image('ICAO-FirstLetter.png')

# %%
airlines.size
# Out:
# 49296

# %%
6162*8
# Out:
# 49296

# %%
rute.size, airlines.size, aerodromi.size
# Out:
# (608967, 49296, 149352)

# %%
antwerpen = pd.read_csv('listings.csv')

# %%
antwerpen
# Out:
#             id                            listing_url       scrape_id  \
# 0      9469806   https://www.airbnb.com/rooms/9469806  20170512105218
# 1     18554132  https://www.airbnb.com/rooms/18554132  20170512105218
# 2     14564139  https://www.airbnb.com/rooms/14564139  20170512105218
# 3     18368449  https://www.airbnb.com/rooms/18368449  20170512105218
# 4     13937329  https://www.airbnb.com/rooms/13937329  20170512105218
# 5     12267515  https://www.airbnb.com/rooms/12267515  20170512105218
# 6     17567044  https://www.airbnb.com/rooms/17567044  20170512105218
# 7      2792584   https://www.airbnb.com/rooms/2792584  20170512105218
# 8     11185079  https://www.airbnb.com/rooms/11185079  20170512105218
# 9     13212065  https://www.airbnb.com/rooms/13212065  20170512105218
# 10     8094749   https://www.airbnb.com/rooms/8094749  20170512105218
# 11    16659420  https://www.airbnb.com/rooms/16659420  20170512105218
# ...

# %%
calendar = pd.read_csv('calendar.csv')

# %%
calendar
# Out:
#         listing_id        date available    price
# 0          9469806  2018-05-11         t  $160.00
# 1          9469806  2018-05-10         t  $160.00
# 2          9469806  2018-05-09         t  $160.00
# 3          9469806  2018-05-08         t  $160.00
# 4          9469806  2018-05-07         t  $160.00
# 5          9469806  2018-05-06         t  $160.00
# 6          9469806  2018-05-05         t  $160.00
# 7          9469806  2018-05-04         t  $160.00
# 8          9469806  2018-05-03         t  $160.00
# 9          9469806  2018-05-02         t  $160.00
# 10         9469806  2018-05-01         t  $160.00
# 11         9469806  2018-04-30         t  $160.00
# 12         9469806  2018-04-29         t  $160.00
# 13         9469806  2018-04-28         t  $160.00
# 14         9469806  2018-04-27         t  $160.00
# 15         9469806  2018-04-26         t  $160.00
# 16         9469806  2018-04-25         t  $160.00
# 17         9469806  2018-04-24         t  $160.00
# ...

# %%
lista = pd.read_csv('listings_antwerp.csv')
lista
# Out:
#             id                                               name    host_id  \
# 0      9469806                      Beautiful apartment in centre   13594534
# 1     18554132                 Characteristic mansion @ Zurenborg   34416465
# 2     14564139                      Spacious apartment in Antwerp   36258248
# 3     18368449        Private room close to the center of Antwerp   32962401
# 4     13937329                       Appartement/Loft met tuintje   16899855
# 5     12267515                 Beautiful sunny house at Zurenborg   13902684
# 6     17567044             SUNNY and SPACIOUS renovated apartment   10658365
# 7      2792584                  Spacious room in car-free street      366948
# 8     11185079                  Retro fifties 2 bedroom apartment    3643884
# 9     13212065  Beautiful, elegant apartment near the City Center   53336187
# 10     8094749                         Unique modern, duplex loft    2793445
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
m = Basemap(resolution='l', # c, l, i, h, f or None
            projection='merc',
            llcrnrlon=1.2, llcrnrlat= 49.4, urcrnrlon=7.7, urcrnrlat=52.7)

# %%
a = aerodromi.loc[aerodromi['IATA'] == 'ANR'].index[0]
Lat = aerodromi.Latitude[a]
b = aerodromi.loc[aerodromi['IATA'] == 'ANR'].index[0]
Lon = aerodromi.Longitude[b]
Lat, Lon
# Out:
# (51.1893997192, 4.46027994156)

# %%
m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color='#f2f2f2',lake_color='#46bcec')
m.drawcoastlines()
m.drawcountries()

x, y = m(Lon, Lat)
plt.plot(x, y, 'ok', markersize=5)
# Out:
# C:\Users\nikol\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# C:\Users\nikol\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %%
def koordinatax():

# %%
rute['Destination']

# %%
aerodromi.set_index('Airport ID', inplace=True)

# %%
aerodromi.loc[aerodromi['City']=='Antwerp']
# Out:
#                                               Name     City  Country IATA  \
# Airport ID
# 299         Antwerp International Airport (Deurne)  Antwerp  Belgium  ANR
# 8491                                      Centraal  Antwerp  Belgium  ZWE
#
#             ICAO   Latitude  Longitude  Altitude Timezone DST  \
# Airport ID
# 299         EBAW  51.189400   4.460280        39        1   E
# 8491          \N  51.217222   4.421111        51        1   E
#
#                 Tz timezone     Type       Source
# Airport ID
# 299         Europe/Brussels  airport  OurAirports
# 8491        Europe/Brussels  unknown         User

# %%
a = set(aerodromi['Source'])
a
# Out:
# {'Legacy', 'OurAirports', 'User'}

# %%
lok = aerodromi.loc[aerodromi['City'] == 'Antwerp']
b = lok.loc[lok['Type'] == 'airport']
b.IATA
# Out:
# Airport ID
# 299    ANR
# Name: IATA, dtype: object

# %%
def broj_ruta_do_odredista(grad):
    kod = aerodromi.loc[aerodromi['City'] == grad]
    kod = kod.loc[kod['Type']== 'airport']
    rute.loc[rute['Destination']== kod ]

# %%
broj_ruta_do_odredista('Antwerp')
# Out:
# C:\Users\nikol\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3140: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   return this.join(other, how=how, return_indexers=return_indexers)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-c18a9f1bf3de> in <module>()
# ----> 1 broj_ruta_do_odredista('Antwerp')
#
# <ipython-input-35-b81614a0da94> in broj_ruta_do_odredista(grad)
#       2     kod = aerodromi.loc[aerodromi['City'] == grad]
#       3     kod = kod.loc[kod['Type']== 'airport']
# ----> 4     rute.loc[rute['Destination']== kod ]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
# ...

# %%
import sympy as sp
sp.init_printing()

# %%
sp.acos?

# %%
fi_1 = sp.Symbol('lambda')

# %%
fi_1
# Out:
# λ

# %%
lok['Latitude', 'Longitude']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Latitude', 'Longitude')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-94cb832f7da0> in <module>()
# ...

# %%
for la in 'latitude':
    phi_1 = lista[la]
    phi_2 = 51.1894
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'l'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-c3531163974e> in <module>()
#       1 for la in 'latitude':
# ...

# %%
a = aerodromi.loc[aerodromi['City'] == 'Antwerp']
b = a.loc[a['Type'] == 'airport'].index[0]
aerodromi.IATA[b]
# Out:
# 'ANR'

# %%
def kod(grad):
    a = zrluke.loc[zrluke['City'] == 'Antwerp']
    in = a.loc[a['Type'] == 'airport'].index[0]
    kod = zrluke.IATA[b]
    return kod
